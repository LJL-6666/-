# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
m = 51212.
f = 40742.
m_perc = m/(m+f)
f_perc = f/(m+f)

# %%
colors = ['navy','lightcoral']
labels = ["Male","Female"]
plt.pie([m_perc,f_perc],labels = labels,autopct = '%1.1f%%',explode=[0,0.05],colors = colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x3e9b630>,
#   <matplotlib.patches.Wedge at 0x3e9bd30>],
#  [Text(-0.1956910285344064, 1.0824532421084738, 'Male'),
#   Text(0.20458618123921923, -1.1316556430495779, 'Female')],
#  [Text(-0.10674056101876711, 0.5904290411500766, '55.7%'),
#   Text(0.11563566765694998, -0.6396314504193266, '44.3%')])

# %%
m = 51212.
f = 40742.
m_perc = m/(m+f)
f_perc = f/(m+f)

colors = ['navy','lightcoral']
labels = ["Male","Female"]

plt.figure(figsize=(8,8))
paches,texts,autotexts=plt.pie([m_perc,f_perc],labels = labels,autopct = '%1.1f%%',explode=[0,0.05],colors = colors)

for text in texts+autotexts:
    text.set_fontsize(20)
for text in autotexts:
    text.set_color('white')
